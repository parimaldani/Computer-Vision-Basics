# %% [markdown]
# <a href="https://colab.research.google.com/github/parimaldani/Computer-Vision-Basics/blob/master/Computer_Vision_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img = Image.open('Images/img.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x7F04662FD400>
